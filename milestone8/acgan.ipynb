# %%
import torch
from torch import nn
import torch.utils.data
import torchvision.datasets as data_set
import torchvision.transforms as transforms
from torch import optim
from torch.autograd import Variable
import numpy as np
import torchvision.utils as vutils

# %%
class generator(nn.Module):

    #generator model
    def __init__(self,in_channels):
        super(generator,self).__init__()
        self.fc1=nn.Linear(in_channels,384)

        self.t1=nn.Sequential(
            nn.ConvTranspose2d(in_channels=384,out_channels=192,kernel_size=(4,4),stride=1,padding=0),
            nn.BatchNorm2d(192),
            nn.ReLU()
        )
        self.t2=nn.Sequential(
            nn.ConvTranspose2d(in_channels=192,out_channels=96,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(96),
            nn.ReLU()
        )
        self.t3=nn.Sequential(
            nn.ConvTranspose2d(in_channels=96,out_channels=48,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU()
        )
        self.t4=nn.Sequential(
            nn.ConvTranspose2d(in_channels=48,out_channels=3,kernel_size=(4,4),stride=2,padding=1),
            nn.Tanh()
        )

    def forward(self,x):
    	x=x.view(-1,110)
    	x=self.fc1(x)
    	x=x.view(-1,384,1,1)
    	x=self.t1(x)
    	x=self.t2(x)
    	x=self.t3(x)
    	x=self.t4(x)
    	return x #output of generator

# %%
class discriminator(nn.Module):

    def __init__(self,classes=10):
        #we have 10 classes in the CIFAR dataset with 6000 images per class.
        super(discriminator,self).__init__()
        self.c1=nn.Sequential(
            nn.Conv2d(in_channels=3,out_channels=16,kernel_size=(3,3),stride=2,padding=1),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c2=nn.Sequential(
            nn.Conv2d(in_channels=16,out_channels=32,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c3=nn.Sequential(
            nn.Conv2d(in_channels=32,out_channels=64,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c4=nn.Sequential(
            nn.Conv2d(in_channels=64,out_channels=128,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c5=nn.Sequential(
            nn.Conv2d(in_channels=128,out_channels=256,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c6=nn.Sequential(
            nn.Conv2d(in_channels=256,out_channels=512,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.fc_source=nn.Linear(4*4*512,1)
        self.fc_class=nn.Linear(4*4*512,classes)
        self.sig=nn.Sigmoid()
        self.soft=nn.Softmax()

    def forward(self,x):

        x=self.c1(x)
        x=self.c2(x)
        x=self.c3(x)
        x=self.c4(x)
        x=self.c5(x)
        x=self.c6(x)
        x=x.view(-1,4*4*512)
        rf=self.sig(self.fc_source(x))#checks source of the data---i.e.--data generated(fake) or from training set(real)
        c=self.soft(self.fc_class(x))#checks class(label) of data--i.e. to which label the data belongs in the CIFAR10 dataset

        return rf,c

# %%
lr=0.0002
epochs=100
batch_size=100
real_label = torch.FloatTensor(batch_size).cuda()
real_label.fill_(1)

fake_label = torch.FloatTensor(batch_size).cuda()
fake_label.fill_(0)


eval_noise = torch.FloatTensor(batch_size, 110, 1, 1).normal_(0, 1)
eval_noise_ = np.random.normal(0, 1, (batch_size, 110))
eval_label = np.random.randint(0, 10, batch_size)
eval_onehot = np.zeros((batch_size, 10))
eval_onehot[np.arange(batch_size), eval_label] = 1
eval_noise_[np.arange(batch_size), :10] = eval_onehot[np.arange(batch_size)]
eval_noise_ = (torch.from_numpy(eval_noise_))
eval_noise.data.copy_(eval_noise_.view(batch_size, 110, 1, 1))
eval_noise=eval_noise.cuda()

# %%
def compute_acc(preds, labels):
	correct = 0
	preds_ = preds.data.max(1)[1]
	correct = preds_.eq(labels.data).cpu().sum()
	acc = float(correct) / float(len(labels.data)) * 100.0
	return acc

def weights_init(m):
		classname = m.__class__.__name__
		if classname.find('Conv') != -1:
			m.weight.data.normal_(0.0, 0.02)
		elif classname.find('BatchNorm') != -1:
			m.weight.data.normal_(1.0, 0.02)
			m.bias.data.fill_(0)

# %%
dataset = data_set.CIFAR10(
				root='data/', download=True,
				transform=transforms.Compose([
					transforms.Resize((32,32)),
					transforms.ToTensor(),
					transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
					]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
# Out:
# Files already downloaded and verified

# %%
gen = generator(110).cuda()
disc = discriminator().cuda()

gen.apply(weights_init)

optimD=optim.Adam(disc.parameters(),lr)
optimG=optim.Adam(gen.parameters(),lr)

source_obj=nn.BCELoss()#source-loss

class_obj=nn.NLLLoss()#class-loss

# %%
for epoch in range(epochs):
	for i,data in enumerate(dataloader,0):
		'''
		At first we will train the discriminator
		'''
		#training with real data----
		optimD.zero_grad()

		image,label=data
		image,label=image.cuda(),label.cuda()

		source_,class_=disc(image)#we feed the real images into the discriminator
		source_ = torch.flatten(source_)
		#print(source_.size())
		source_error=source_obj(source_,real_label)#label for real images--1; for fake images--0
		class_error=class_obj(class_,label)
		error_real=source_error+class_error
		error_real.backward()
		optimD.step()


		accuracy=compute_acc(class_,label)#getting the current classification accuracy

		#training with fake data now----


		noise_ = np.random.normal(0, 1, (batch_size, 110))#generating noise by random sampling from a normal distribution

		label=np.random.randint(0,10,batch_size)#generating labels for the entire batch

		noise=((torch.from_numpy(noise_)).float())
		noise=noise.cuda()#converting to tensors in order to work with pytorch

		label=((torch.from_numpy(label)).long())
		label=label.cuda()#converting to tensors in order to work with pytorch

		noise_image=gen(noise)
		#print(noise_image.size())

		source_,class_=disc(noise_image.detach())#we will be using this tensor later on
		source_ = torch.flatten(source_)
		#print(source_.size())
		source_error=source_obj(source_,fake_label)#label for real images--1; for fake images--0
		class_error=class_obj(class_,label)
		error_fake=source_error+class_error
		error_fake.backward()
		optimD.step()


		'''
		Now we train the generator as we have finished updating weights of the discriminator
		'''

		gen.zero_grad()
		source_,class_=disc(noise_image)
		source_ = torch.flatten(source_)
		source_error=source_obj(source_,real_label)#The generator tries to pass its images as real---so we pass the images as real to the cost function
		class_error=class_obj(class_,label)
		error_gen=source_error+class_error
		error_gen.backward()
		optimG.step()
		iteration_now = epoch * len(dataloader) + i


		print("Epoch--[{} / {}], Loss_Discriminator--[{}], Loss_Generator--[{}],Accuracy--[{}]".format(epoch+1,epochs,error_fake,error_gen,accuracy))


		'''Saving the images by the epochs'''
		if i % 100 == 0:
			constructed = gen(eval_noise)
			vutils.save_image(
				constructed.data,
				'%s/results_epoch_%03d.png' % ('images/', epoch)
				)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Epoch--[1 / 100], Loss_Discriminator--[1.3428053855895996], Loss_Generator--[0.15258684754371643],Accuracy--[11.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.9845799207687378], Loss_Generator--[0.06330438703298569],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.8369139432907104], Loss_Generator--[0.1509179174900055],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.4378085136413574], Loss_Generator--[0.31330859661102295],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8928163647651672], Loss_Generator--[0.5668041110038757],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.6219097375869751], Loss_Generator--[0.7101193070411682],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5710292458534241], Loss_Generator--[0.6549040675163269],Accuracy--[7.000000000000001]
# Epoch--[1 / 100], Loss_Discriminator--[0.6909899711608887], Loss_Generator--[0.5906869173049927],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9644477367401123], Loss_Generator--[0.35836490988731384],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.162299633026123], Loss_Generator--[0.2436973750591278],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.3282854557037354], Loss_Generator--[0.24361801147460938],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.3252527713775635], Loss_Generator--[0.21385732293128967],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.2798585891723633], Loss_Generator--[0.3127274811267853],Accuracy--[12.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0906766653060913], Loss_Generator--[0.4039209485054016],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9646104574203491], Loss_Generator--[0.5478760004043579],Accuracy--[7.000000000000001]
# Epoch--[1 / 100], Loss_Discriminator--[0.7126237750053406], Loss_Generator--[0.6253985166549683],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8077831864356995], Loss_Generator--[0.6345076560974121],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7865700125694275], Loss_Generator--[0.6224526762962341],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8356034755706787], Loss_Generator--[0.5697968006134033],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9697890281677246], Loss_Generator--[0.44650840759277344],Accuracy--[7.000000000000001]
# Epoch--[1 / 100], Loss_Discriminator--[1.041820764541626], Loss_Generator--[0.42696040868759155],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0365800857543945], Loss_Generator--[0.4062648117542267],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0016533136367798], Loss_Generator--[0.43420475721359253],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0852532386779785], Loss_Generator--[0.5080668330192566],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.864067792892456], Loss_Generator--[0.5674751996994019],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8500669002532959], Loss_Generator--[0.6615649461746216],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.6998848915100098], Loss_Generator--[0.6428002715110779],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9063853621482849], Loss_Generator--[0.57050621509552],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8969482779502869], Loss_Generator--[0.5001593232154846],Accuracy--[12.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9692676663398743], Loss_Generator--[0.4812968969345093],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0460896492004395], Loss_Generator--[0.42221981287002563],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.0544956922531128], Loss_Generator--[0.4124508798122406],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.983730673789978], Loss_Generator--[0.44619977474212646],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9602617025375366], Loss_Generator--[0.437389612197876],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.057202696800232], Loss_Generator--[0.6641380786895752],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8686250448226929], Loss_Generator--[0.6285630464553833],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8058573007583618], Loss_Generator--[0.7027401924133301],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7363210916519165], Loss_Generator--[0.8365282416343689],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7109218239784241], Loss_Generator--[0.7450608015060425],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8037160634994507], Loss_Generator--[0.7346012592315674],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.8118080496788025], Loss_Generator--[0.7370576858520508],Accuracy--[11.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7531458139419556], Loss_Generator--[0.6929192543029785],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7204574346542358], Loss_Generator--[0.8007588386535645],Accuracy--[11.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.6498636603355408], Loss_Generator--[0.8103817701339722],Accuracy--[12.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5789023041725159], Loss_Generator--[1.023119330406189],Accuracy--[9.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5219032168388367], Loss_Generator--[0.9645169973373413],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5392459630966187], Loss_Generator--[1.0196174383163452],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5265633463859558], Loss_Generator--[1.1482176780700684],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5344457030296326], Loss_Generator--[1.2030820846557617],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5215409398078918], Loss_Generator--[1.1975802183151245],Accuracy--[8.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5156068205833435], Loss_Generator--[1.2075822353363037],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.4134952127933502], Loss_Generator--[1.2692596912384033],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5141938328742981], Loss_Generator--[1.2771693468093872],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.6163924932479858], Loss_Generator--[1.324294090270996],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[0.5363813042640686], Loss_Generator--[1.679561734199524],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.36005067825317383], Loss_Generator--[1.9831995964050293],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3212168216705322], Loss_Generator--[1.8535358905792236],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.33659422397613525], Loss_Generator--[2.0935542583465576],Accuracy--[11.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.41791412234306335], Loss_Generator--[1.8456833362579346],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.4831330180168152], Loss_Generator--[1.6836761236190796],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.42007842659950256], Loss_Generator--[1.784751534461975],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5551683306694031], Loss_Generator--[1.8055574893951416],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.4566096067428589], Loss_Generator--[1.9314881563186646],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.42292165756225586], Loss_Generator--[2.041234254837036],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.43084558844566345], Loss_Generator--[1.8588662147521973],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3297557532787323], Loss_Generator--[1.9782615900039673],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.37321656942367554], Loss_Generator--[2.4155848026275635],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2130230963230133], Loss_Generator--[2.0353610515594482],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.19810757040977478], Loss_Generator--[2.297271490097046],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.26163941621780396], Loss_Generator--[1.9626891613006592],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2426750659942627], Loss_Generator--[2.093935012817383],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.23007269203662872], Loss_Generator--[2.4522511959075928],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.15388727188110352], Loss_Generator--[2.933518886566162],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.10123901069164276], Loss_Generator--[3.483410596847534],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0686744824051857], Loss_Generator--[3.178219795227051],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.029480427503585815], Loss_Generator--[3.1022937297821045],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.020508840680122375], Loss_Generator--[3.4151804447174072],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.02093277871608734], Loss_Generator--[3.131434917449951],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1063738539814949], Loss_Generator--[2.915466547012329],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06452217698097229], Loss_Generator--[3.087597131729126],Accuracy--[31.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12922385334968567], Loss_Generator--[3.1547536849975586],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0034804046154022217], Loss_Generator--[3.6789324283599854],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.02103564888238907], Loss_Generator--[3.3633694648742676],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03034833073616028], Loss_Generator--[3.6003634929656982],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04819866269826889], Loss_Generator--[3.7877185344696045],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.033184558153152466], Loss_Generator--[4.220283508300781],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.010356999933719635], Loss_Generator--[4.076894283294678],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04490460455417633], Loss_Generator--[4.3256516456604],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.011607058346271515], Loss_Generator--[3.844916582107544],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.015551768243312836], Loss_Generator--[4.0114850997924805],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.015001729130744934], Loss_Generator--[4.265253067016602],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03743695840239525], Loss_Generator--[4.077954292297363],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04386015981435776], Loss_Generator--[4.103481769561768],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06042058765888214], Loss_Generator--[3.894078493118286],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06377362459897995], Loss_Generator--[3.9991252422332764],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0760074332356453], Loss_Generator--[4.222564220428467],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.045334555208683014], Loss_Generator--[4.623302936553955],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04357367381453514], Loss_Generator--[4.543796062469482],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05746643990278244], Loss_Generator--[4.447332382202148],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.05505083501338959], Loss_Generator--[4.179488658905029],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0003476738929748535], Loss_Generator--[4.247182369232178],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0001550614833831787], Loss_Generator--[3.6058189868927],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03818637877702713], Loss_Generator--[4.346635818481445],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.05093670263886452], Loss_Generator--[4.459039688110352],Accuracy--[30.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04111863672733307], Loss_Generator--[4.590989589691162],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.011502780020236969], Loss_Generator--[5.455103397369385],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06612806022167206], Loss_Generator--[4.954272747039795],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07401468604803085], Loss_Generator--[5.18125057220459],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09787219762802124], Loss_Generator--[4.877406597137451],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06645350158214569], Loss_Generator--[5.340490818023682],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.033776573836803436], Loss_Generator--[4.816832065582275],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.015366382896900177], Loss_Generator--[4.677435874938965],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04510214924812317], Loss_Generator--[4.4088263511657715],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04811123013496399], Loss_Generator--[4.011544704437256],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.042734578251838684], Loss_Generator--[4.839686870574951],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.026783592998981476], Loss_Generator--[4.585812568664551],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.015138395130634308], Loss_Generator--[4.789679050445557],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.006517753005027771], Loss_Generator--[5.358817100524902],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03936455771327019], Loss_Generator--[5.188820838928223],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10740351676940918], Loss_Generator--[4.644710540771484],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01693277806043625], Loss_Generator--[4.512258052825928],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01929955929517746], Loss_Generator--[4.242403984069824],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07231587171554565], Loss_Generator--[4.3112406730651855],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.004241347312927246], Loss_Generator--[4.641117095947266],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0037419945001602173], Loss_Generator--[4.51588249206543],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.02603912353515625], Loss_Generator--[4.847531318664551],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05583938583731651], Loss_Generator--[5.15095329284668],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10580901801586151], Loss_Generator--[5.055542945861816],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0183340385556221], Loss_Generator--[5.3033881187438965],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.13121481239795685], Loss_Generator--[4.6500444412231445],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08275476098060608], Loss_Generator--[4.514425754547119],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06570060551166534], Loss_Generator--[4.840993404388428],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06218468397855759], Loss_Generator--[4.9379048347473145],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08398686349391937], Loss_Generator--[5.04393196105957],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04948893561959267], Loss_Generator--[5.001710891723633],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09179075062274933], Loss_Generator--[4.751316070556641],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.13753168284893036], Loss_Generator--[5.0632643699646],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.034463174641132355], Loss_Generator--[5.505821228027344],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.11810752749443054], Loss_Generator--[5.0893120765686035],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09726347029209137], Loss_Generator--[5.581409931182861],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07196629047393799], Loss_Generator--[5.197864532470703],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.032763734459877014], Loss_Generator--[4.9973039627075195],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0667734146118164], Loss_Generator--[5.110273838043213],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.061708543449640274], Loss_Generator--[4.664854049682617],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.008938834071159363], Loss_Generator--[5.75261926651001],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05926067382097244], Loss_Generator--[5.187842845916748],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0623244047164917], Loss_Generator--[5.141627788543701],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03910329192876816], Loss_Generator--[5.1098432540893555],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.059398092329502106], Loss_Generator--[4.658129692077637],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.016794927418231964], Loss_Generator--[4.484392166137695],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04165343940258026], Loss_Generator--[4.661982536315918],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07059334963560104], Loss_Generator--[5.276665687561035],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.003489449620246887], Loss_Generator--[4.772723197937012],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08526003360748291], Loss_Generator--[4.2906694412231445],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0032383203506469727], Loss_Generator--[4.630605220794678],Accuracy--[12.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.029740437865257263], Loss_Generator--[5.033570766448975],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.024307698011398315], Loss_Generator--[4.581142425537109],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08291634917259216], Loss_Generator--[4.626297473907471],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.09087038040161133], Loss_Generator--[3.1787490844726562],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0711301863193512], Loss_Generator--[3.713751792907715],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07683932781219482], Loss_Generator--[4.309014320373535],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.032810527831315994], Loss_Generator--[4.863764762878418],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0439298078417778], Loss_Generator--[4.517369270324707],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.039507314562797546], Loss_Generator--[4.357968330383301],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[0.15596885979175568], Loss_Generator--[3.586282730102539],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.032309338450431824], Loss_Generator--[3.9835619926452637],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03815719485282898], Loss_Generator--[4.021060943603516],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03628401458263397], Loss_Generator--[3.3838062286376953],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5719666481018066], Loss_Generator--[2.477419137954712],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5839293599128723], Loss_Generator--[3.274326801300049],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07083578407764435], Loss_Generator--[4.993490695953369],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06546968966722488], Loss_Generator--[3.3649022579193115],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3211429715156555], Loss_Generator--[2.4182629585266113],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9787542223930359], Loss_Generator--[2.644608736038208],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.045506954193115234], Loss_Generator--[4.266394138336182],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.007801860570907593], Loss_Generator--[5.772541046142578],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.02463357150554657], Loss_Generator--[5.377860069274902],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04657358676195145], Loss_Generator--[3.184168815612793],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2945215404033661], Loss_Generator--[3.039405584335327],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2344861626625061], Loss_Generator--[3.307279348373413],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08767911791801453], Loss_Generator--[4.761247634887695],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03414563089609146], Loss_Generator--[4.6537065505981445],Accuracy--[10.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01465289294719696], Loss_Generator--[4.507692813873291],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.033246174454689026], Loss_Generator--[4.369531154632568],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.016508646309375763], Loss_Generator--[3.5389623641967773],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.037453360855579376], Loss_Generator--[2.658264636993408],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1102437973022461], Loss_Generator--[3.4638478755950928],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.020210042595863342], Loss_Generator--[4.192716598510742],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.025866620242595673], Loss_Generator--[4.420451641082764],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06288070231676102], Loss_Generator--[3.9895780086517334],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.16521701216697693], Loss_Generator--[3.0072481632232666],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07706517726182938], Loss_Generator--[3.2801589965820312],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3339567482471466], Loss_Generator--[3.118227481842041],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.020339392125606537], Loss_Generator--[3.6633036136627197],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.15889687836170197], Loss_Generator--[3.568784475326538],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.078203484416008], Loss_Generator--[3.5441722869873047],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08791792392730713], Loss_Generator--[3.7119476795196533],Accuracy--[31.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04593246430158615], Loss_Generator--[3.972510576248169],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.05741853266954422], Loss_Generator--[3.7370738983154297],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.016997918486595154], Loss_Generator--[3.7671546936035156],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.008516110479831696], Loss_Generator--[4.312349319458008],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07006770372390747], Loss_Generator--[3.2697248458862305],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.013853825628757477], Loss_Generator--[4.4111552238464355],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.01966477930545807], Loss_Generator--[4.514258861541748],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.004889942705631256], Loss_Generator--[4.427005767822266],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05446099117398262], Loss_Generator--[5.368447303771973],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05459611862897873], Loss_Generator--[5.789944648742676],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.047593627125024796], Loss_Generator--[6.161365509033203],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10250487178564072], Loss_Generator--[6.314545631408691],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.034708715975284576], Loss_Generator--[6.33234977722168],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.044362571090459824], Loss_Generator--[5.701457977294922],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06851714104413986], Loss_Generator--[5.116962909698486],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.02912157028913498], Loss_Generator--[4.591683864593506],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.008252494037151337], Loss_Generator--[5.631882667541504],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06410831958055496], Loss_Generator--[5.753851890563965],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04525874927639961], Loss_Generator--[5.9466986656188965],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10218991339206696], Loss_Generator--[6.375955581665039],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.057635992765426636], Loss_Generator--[5.101942539215088],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09622194617986679], Loss_Generator--[5.4521050453186035],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.030091166496276855], Loss_Generator--[4.322421550750732],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08411560952663422], Loss_Generator--[4.301395416259766],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.10929390043020248], Loss_Generator--[4.196934223175049],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0774817243218422], Loss_Generator--[5.6517252922058105],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.02282792329788208], Loss_Generator--[5.246843338012695],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0246826633810997], Loss_Generator--[5.492184638977051],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07440705597400665], Loss_Generator--[4.180679798126221],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[0.19834774732589722], Loss_Generator--[4.181057453155518],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.11560088396072388], Loss_Generator--[3.457857608795166],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12880492210388184], Loss_Generator--[3.7112507820129395],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07501756399869919], Loss_Generator--[3.784453868865967],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.030773252248764038], Loss_Generator--[3.955977439880371],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.027964189648628235], Loss_Generator--[4.597639560699463],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.014555685222148895], Loss_Generator--[4.318178653717041],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.01828017830848694], Loss_Generator--[3.677973508834839],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.01927661895751953], Loss_Generator--[3.312156915664673],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.14107787609100342], Loss_Generator--[2.456862211227417],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3955537676811218], Loss_Generator--[3.2291219234466553],Accuracy--[31.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03045216202735901], Loss_Generator--[4.176630020141602],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04259701073169708], Loss_Generator--[5.925106525421143],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08504467457532883], Loss_Generator--[4.9745378494262695],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.055171407759189606], Loss_Generator--[3.861052989959717],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.027329392731189728], Loss_Generator--[4.043773651123047],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.22015830874443054], Loss_Generator--[3.5299293994903564],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.017368972301483154], Loss_Generator--[3.9899237155914307],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.024803385138511658], Loss_Generator--[4.199695587158203],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01391652598977089], Loss_Generator--[4.583428859710693],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.029929980635643005], Loss_Generator--[4.240682125091553],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.025077372789382935], Loss_Generator--[4.084120750427246],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03219883143901825], Loss_Generator--[4.858640670776367],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0147525854408741], Loss_Generator--[5.0095319747924805],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08137673139572144], Loss_Generator--[5.446410655975342],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08116436004638672], Loss_Generator--[5.7129435539245605],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.040311116725206375], Loss_Generator--[4.192617893218994],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.22286441922187805], Loss_Generator--[2.794133186340332],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.17062115669250488], Loss_Generator--[3.51474666595459],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.013728931546211243], Loss_Generator--[4.990940570831299],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.027664989233016968], Loss_Generator--[5.350137233734131],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03577796742320061], Loss_Generator--[4.66741418838501],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10899707674980164], Loss_Generator--[4.858068943023682],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0030577704310417175], Loss_Generator--[3.148970365524292],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3703804314136505], Loss_Generator--[3.265451431274414],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.009555965662002563], Loss_Generator--[4.36356782913208],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05659471079707146], Loss_Generator--[5.137133598327637],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07231710851192474], Loss_Generator--[5.426534652709961],Accuracy--[31.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01371641457080841], Loss_Generator--[5.105075836181641],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09736863523721695], Loss_Generator--[4.645938873291016],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.17065587639808655], Loss_Generator--[3.485264301300049],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.003224603831768036], Loss_Generator--[4.137974739074707],Accuracy--[32.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12320566922426224], Loss_Generator--[3.3060669898986816],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.14098674058914185], Loss_Generator--[3.933044195175171],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03050314635038376], Loss_Generator--[5.227545261383057],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.029737770557403564], Loss_Generator--[4.979829788208008],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0658312737941742], Loss_Generator--[4.306644916534424],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.18148069083690643], Loss_Generator--[2.9455485343933105],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3274812698364258], Loss_Generator--[2.694331169128418],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.18291738629341125], Loss_Generator--[3.7104597091674805],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06885500252246857], Loss_Generator--[5.4856791496276855],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.016483232378959656], Loss_Generator--[5.521641731262207],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.026523783802986145], Loss_Generator--[4.321804523468018],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06956800818443298], Loss_Generator--[4.768940448760986],Accuracy--[33.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.05631346255540848], Loss_Generator--[3.161658763885498],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.17577971518039703], Loss_Generator--[1.973914623260498],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2925499677658081], Loss_Generator--[3.30440092086792],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04277433454990387], Loss_Generator--[3.7936599254608154],Accuracy--[31.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04200296103954315], Loss_Generator--[4.133188724517822],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.002400234341621399], Loss_Generator--[4.1656928062438965],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1380217969417572], Loss_Generator--[2.6410434246063232],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.19846361875534058], Loss_Generator--[2.80448317527771],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.34722214937210083], Loss_Generator--[2.886539936065674],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2490399032831192], Loss_Generator--[3.1815247535705566],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05236586183309555], Loss_Generator--[4.910676002502441],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06834280490875244], Loss_Generator--[3.4447717666625977],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08385755121707916], Loss_Generator--[2.697314739227295],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1654302030801773], Loss_Generator--[2.2724509239196777],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3473333716392517], Loss_Generator--[2.373692274093628],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1475406438112259], Loss_Generator--[3.525172233581543],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.023252658545970917], Loss_Generator--[4.8070902824401855],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.014181308448314667], Loss_Generator--[5.224457263946533],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.12037358433008194], Loss_Generator--[4.722435474395752],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.009341984987258911], Loss_Generator--[3.893401622772217],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.17056210339069366], Loss_Generator--[3.1290884017944336],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0683039203286171], Loss_Generator--[2.7024643421173096],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.2811104953289032], Loss_Generator--[2.6544570922851562],Accuracy--[33.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.02185407280921936], Loss_Generator--[4.583536624908447],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[-0.046584680676460266], Loss_Generator--[4.767602443695068],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01982167363166809], Loss_Generator--[4.863173961639404],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04858541116118431], Loss_Generator--[3.943289041519165],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.26668474078178406], Loss_Generator--[2.1113274097442627],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.45907875895500183], Loss_Generator--[2.7232260704040527],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.10130688548088074], Loss_Generator--[5.139236927032471],Accuracy--[33.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04788218066096306], Loss_Generator--[5.0931572914123535],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[0.02316650003194809], Loss_Generator--[4.302340507507324],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.10656425356864929], Loss_Generator--[2.865454912185669],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.24858658015727997], Loss_Generator--[3.2497525215148926],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2691982388496399], Loss_Generator--[2.803518533706665],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1377759873867035], Loss_Generator--[4.356325626373291],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.14389072358608246], Loss_Generator--[3.7205257415771484],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.36038336157798767], Loss_Generator--[1.6889704465866089],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.27860027551651], Loss_Generator--[2.327847480773926],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.25805211067199707], Loss_Generator--[3.6325786113739014],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.041577354073524475], Loss_Generator--[5.106042861938477],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0026096031069755554], Loss_Generator--[4.197267055511475],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.20715980231761932], Loss_Generator--[1.7664120197296143],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[1.8973106145858765], Loss_Generator--[1.1889188289642334],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.579892635345459], Loss_Generator--[3.1422646045684814],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05850134789943695], Loss_Generator--[4.886964321136475],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.036146290600299835], Loss_Generator--[2.083538770675659],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5900586843490601], Loss_Generator--[0.6144274473190308],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.9594060778617859], Loss_Generator--[1.1447559595108032],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.6671488881111145], Loss_Generator--[2.6549267768859863],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.04105226695537567], Loss_Generator--[4.084959030151367],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0719718411564827], Loss_Generator--[5.3199143409729],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.036043930798769], Loss_Generator--[4.329982280731201],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[0.08362601697444916], Loss_Generator--[2.313396692276001],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5977975726127625], Loss_Generator--[1.8144325017929077],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.34216153621673584], Loss_Generator--[2.5098049640655518],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.09365570545196533], Loss_Generator--[3.907137870788574],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.10601015388965607], Loss_Generator--[3.9971885681152344],Accuracy--[23.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.025774694979190826], Loss_Generator--[3.076645612716675],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.033420346677303314], Loss_Generator--[3.0499441623687744],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12919288873672485], Loss_Generator--[1.9771943092346191],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.42019370198249817], Loss_Generator--[2.109269142150879],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.19142228364944458], Loss_Generator--[3.077202081680298],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06729108095169067], Loss_Generator--[4.449877738952637],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.039744921028614044], Loss_Generator--[4.012401103973389],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.05548765882849693], Loss_Generator--[3.49320125579834],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.025440335273742676], Loss_Generator--[3.5512568950653076],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.011890336871147156], Loss_Generator--[3.9265475273132324],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.023596256971359253], Loss_Generator--[3.1638638973236084],Accuracy--[13.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12062564492225647], Loss_Generator--[2.438647747039795],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08744260668754578], Loss_Generator--[2.6652114391326904],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5132169723510742], Loss_Generator--[2.660182476043701],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.003996610641479492], Loss_Generator--[3.7167327404022217],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.016273826360702515], Loss_Generator--[3.846362352371216],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.19711104035377502], Loss_Generator--[2.6353816986083984],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.5215414762496948], Loss_Generator--[1.4845545291900635],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.7429354786872864], Loss_Generator--[2.465151309967041],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.042544133961200714], Loss_Generator--[5.047754287719727],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07498842477798462], Loss_Generator--[3.8236193656921387],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03642520308494568], Loss_Generator--[3.5423192977905273],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.016046784818172455], Loss_Generator--[3.200756788253784],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.007955789566040039], Loss_Generator--[2.753553628921509],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.38649842143058777], Loss_Generator--[2.9596312046051025],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.18997207283973694], Loss_Generator--[3.3555500507354736],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1220642477273941], Loss_Generator--[4.050619602203369],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.11809433251619339], Loss_Generator--[6.1747894287109375],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07313191890716553], Loss_Generator--[5.254143714904785],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.08820657432079315], Loss_Generator--[4.896677017211914],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.01386214792728424], Loss_Generator--[4.371342182159424],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.03420597314834595], Loss_Generator--[3.3368303775787354],Accuracy--[11.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.2083790898323059], Loss_Generator--[2.6324145793914795],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3184520900249481], Loss_Generator--[2.8395605087280273],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.3045335114002228], Loss_Generator--[3.4270644187927246],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06259714812040329], Loss_Generator--[5.065634727478027],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04453403875231743], Loss_Generator--[4.306212902069092],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.09496697783470154], Loss_Generator--[2.833068370819092],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.16948068141937256], Loss_Generator--[2.3550641536712646],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.42329543828964233], Loss_Generator--[2.3614907264709473],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.08891551941633224], Loss_Generator--[4.462531566619873],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03226853907108307], Loss_Generator--[6.701173305511475],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07320751994848251], Loss_Generator--[6.238585472106934],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09426026791334152], Loss_Generator--[4.516149520874023],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.028444714844226837], Loss_Generator--[4.520827293395996],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.1235189214348793], Loss_Generator--[2.699155330657959],Accuracy--[14.000000000000002]
# Epoch--[1 / 100], Loss_Discriminator--[0.3484230935573578], Loss_Generator--[2.3467257022857666],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.00912940502166748], Loss_Generator--[3.73984956741333],Accuracy--[24.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.00393909215927124], Loss_Generator--[4.880425453186035],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.06537844240665436], Loss_Generator--[6.035874366760254],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.09473362565040588], Loss_Generator--[6.380146026611328],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04240347817540169], Loss_Generator--[4.335109233856201],Accuracy--[16.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04115905612707138], Loss_Generator--[4.263664245605469],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.15314806997776031], Loss_Generator--[3.275585889816284],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.10339891910552979], Loss_Generator--[3.7826650142669678],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.003132842481136322], Loss_Generator--[4.793214797973633],Accuracy--[17.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04407237097620964], Loss_Generator--[5.07801628112793],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07323416322469711], Loss_Generator--[4.977518558502197],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04765104129910469], Loss_Generator--[5.140881061553955],Accuracy--[22.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0359833762049675], Loss_Generator--[4.50911283493042],Accuracy--[20.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.026874937117099762], Loss_Generator--[4.822678089141846],Accuracy--[33.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.0017335116863250732], Loss_Generator--[4.792397499084473],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.030886109918355942], Loss_Generator--[4.0235114097595215],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[-0.0444972924888134], Loss_Generator--[3.8448598384857178],Accuracy--[15.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.12662795186042786], Loss_Generator--[3.346302032470703],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.10857972502708435], Loss_Generator--[4.0367279052734375],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.03951675444841385], Loss_Generator--[4.16175651550293],Accuracy--[21.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.046726636588573456], Loss_Generator--[4.5086517333984375],Accuracy--[28.999999999999996]
# Epoch--[1 / 100], Loss_Discriminator--[0.054226599633693695], Loss_Generator--[3.8215999603271484],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07445956766605377], Loss_Generator--[3.7413558959960938],Accuracy--[25.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.07053550332784653], Loss_Generator--[4.483611583709717],Accuracy--[28.000000000000004]
# Epoch--[1 / 100], Loss_Discriminator--[0.019106723368167877], Loss_Generator--[4.624146938323975],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07039543241262436], Loss_Generator--[5.2532267570495605],Accuracy--[18.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.04878736287355423], Loss_Generator--[4.511513710021973],Accuracy--[19.0]
# ...
# Epoch--[26 / 100], Loss_Discriminator--[0.16215425729751587], Loss_Generator--[5.8618927001953125],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08736950159072876], Loss_Generator--[9.730616569519043],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.006003417074680328], Loss_Generator--[5.454416275024414],Accuracy--[25.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.17006348073482513], Loss_Generator--[1.7097283601760864],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[1.5794330835342407], Loss_Generator--[1.9889137744903564],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.3145523965358734], Loss_Generator--[5.25891637802124],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.0666763186454773], Loss_Generator--[4.964996337890625],Accuracy--[30.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08012480288743973], Loss_Generator--[9.730338096618652],Accuracy--[47.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.04839465394616127], Loss_Generator--[12.31324577331543],Accuracy--[43.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09969820082187653], Loss_Generator--[13.31037425994873],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.058835141360759735], Loss_Generator--[13.048656463623047],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.1566031575202942], Loss_Generator--[11.38532829284668],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.11025038361549377], Loss_Generator--[11.477058410644531],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.022896088659763336], Loss_Generator--[3.269972324371338],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.02283131331205368], Loss_Generator--[4.992211818695068],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.1151898130774498], Loss_Generator--[7.013319492340088],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10975297540426254], Loss_Generator--[4.767746448516846],Accuracy--[43.0]
# Epoch--[26 / 100], Loss_Discriminator--[3.319812059402466], Loss_Generator--[2.844632863998413],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.05782603472471237], Loss_Generator--[7.9027276039123535],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07141131162643433], Loss_Generator--[13.750399589538574],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07554079592227936], Loss_Generator--[15.531065940856934],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12139836698770523], Loss_Generator--[15.392772674560547],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.1024237647652626], Loss_Generator--[11.573126792907715],Accuracy--[42.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.05917171761393547], Loss_Generator--[8.82579517364502],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09769970178604126], Loss_Generator--[7.848834037780762],Accuracy--[46.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.034285396337509155], Loss_Generator--[6.361822128295898],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.01873394474387169], Loss_Generator--[3.417872428894043],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.9636902809143066], Loss_Generator--[3.2930376529693604],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.36219531297683716], Loss_Generator--[3.669157028198242],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09902516007423401], Loss_Generator--[10.674745559692383],Accuracy--[44.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10253716260194778], Loss_Generator--[15.254858016967773],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.1278533786535263], Loss_Generator--[15.10586929321289],Accuracy--[44.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.15321506559848785], Loss_Generator--[15.397780418395996],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06914612650871277], Loss_Generator--[14.068175315856934],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.04455025866627693], Loss_Generator--[13.231067657470703],Accuracy--[43.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06348920613527298], Loss_Generator--[10.92324447631836],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.14781032502651215], Loss_Generator--[11.817066192626953],Accuracy--[41.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10538820177316666], Loss_Generator--[8.513618469238281],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12850338220596313], Loss_Generator--[10.180115699768066],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.11172421276569366], Loss_Generator--[5.157790184020996],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.035490550100803375], Loss_Generator--[4.417262554168701],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.5219074487686157], Loss_Generator--[4.200545310974121],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.0061686113476753235], Loss_Generator--[6.438277244567871],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.0734974816441536], Loss_Generator--[5.873011589050293],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07040456682443619], Loss_Generator--[7.111931324005127],Accuracy--[43.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.4160941243171692], Loss_Generator--[3.964129686355591],Accuracy--[28.999999999999996]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07305596768856049], Loss_Generator--[5.739260673522949],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07194671034812927], Loss_Generator--[9.177711486816406],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06294827163219452], Loss_Generator--[5.7492170333862305],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12964023649692535], Loss_Generator--[7.2073564529418945],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.0994463860988617], Loss_Generator--[7.529351234436035],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.11163215339183807], Loss_Generator--[2.70282244682312],Accuracy--[48.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.003945872187614441], Loss_Generator--[6.754269123077393],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06726130843162537], Loss_Generator--[6.95273494720459],Accuracy--[41.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.13089211285114288], Loss_Generator--[4.196794509887695],Accuracy--[41.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.013661898672580719], Loss_Generator--[6.3154377937316895],Accuracy--[28.000000000000004]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06273484230041504], Loss_Generator--[1.904774785041809],Accuracy--[42.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.35172808170318604], Loss_Generator--[2.1022934913635254],Accuracy--[30.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.13113778829574585], Loss_Generator--[2.28896427154541],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.19709202647209167], Loss_Generator--[3.644988536834717],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.15984617173671722], Loss_Generator--[7.701260089874268],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10955934226512909], Loss_Generator--[8.86595630645752],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10457046329975128], Loss_Generator--[10.071039199829102],Accuracy--[30.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.04887760058045387], Loss_Generator--[3.978973627090454],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.30202946066856384], Loss_Generator--[2.065927505493164],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.2162558138370514], Loss_Generator--[4.4030585289001465],Accuracy--[42.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.3327747583389282], Loss_Generator--[3.4217042922973633],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.4959608316421509], Loss_Generator--[4.936464309692383],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08755100518465042], Loss_Generator--[8.215958595275879],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12762069702148438], Loss_Generator--[11.683683395385742],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09680324792861938], Loss_Generator--[9.240633964538574],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07078167796134949], Loss_Generator--[6.987697601318359],Accuracy--[44.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.05673583969473839], Loss_Generator--[3.4373254776000977],Accuracy--[41.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.5380530953407288], Loss_Generator--[3.2499773502349854],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.3464406132698059], Loss_Generator--[3.5747368335723877],Accuracy--[42.0]
# Epoch--[26 / 100], Loss_Discriminator--[1.211198091506958], Loss_Generator--[2.691424608230591],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.10587137937545776], Loss_Generator--[7.578157901763916],Accuracy--[28.999999999999996]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08522339165210724], Loss_Generator--[10.972311973571777],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08877868950366974], Loss_Generator--[14.884929656982422],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.1106860414147377], Loss_Generator--[12.427093505859375],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08484268933534622], Loss_Generator--[10.982772827148438],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07477214932441711], Loss_Generator--[4.243022441864014],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.23657600581645966], Loss_Generator--[1.625956654548645],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.5563421249389648], Loss_Generator--[2.6326019763946533],Accuracy--[44.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.6702038049697876], Loss_Generator--[3.715071201324463],Accuracy--[28.999999999999996]
# Epoch--[26 / 100], Loss_Discriminator--[-0.01675356924533844], Loss_Generator--[9.030302047729492],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10643324255943298], Loss_Generator--[12.080337524414062],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.05230707675218582], Loss_Generator--[12.572669982910156],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.14529255032539368], Loss_Generator--[11.443870544433594],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07853042334318161], Loss_Generator--[7.143692493438721],Accuracy--[47.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.14209899306297302], Loss_Generator--[10.92894172668457],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.058403972536325455], Loss_Generator--[10.318327903747559],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08478248864412308], Loss_Generator--[6.975240707397461],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.13956975936889648], Loss_Generator--[4.049532890319824],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.0037399940192699432], Loss_Generator--[3.3614227771759033],Accuracy--[43.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.08636566251516342], Loss_Generator--[1.9783644676208496],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.3440133333206177], Loss_Generator--[1.4843864440917969],Accuracy--[46.0]
# Epoch--[26 / 100], Loss_Discriminator--[1.782021164894104], Loss_Generator--[3.667982578277588],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.055770695209503174], Loss_Generator--[6.295003890991211],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.13320386409759521], Loss_Generator--[8.544264793395996],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.13253773748874664], Loss_Generator--[9.92111587524414],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12599770724773407], Loss_Generator--[9.548646926879883],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10900715738534927], Loss_Generator--[6.887966632843018],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10511257499456406], Loss_Generator--[7.798284530639648],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.3123527467250824], Loss_Generator--[3.873262405395508],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06780757009983063], Loss_Generator--[4.958981037139893],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.10954838246107101], Loss_Generator--[3.666482448577881],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.15705473721027374], Loss_Generator--[2.4604804515838623],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.20371350646018982], Loss_Generator--[2.5907795429229736],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.5534806847572327], Loss_Generator--[6.865074157714844],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09632828086614609], Loss_Generator--[6.697601795196533],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.07480575889348984], Loss_Generator--[6.255918025970459],Accuracy--[40.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06916426867246628], Loss_Generator--[4.888574123382568],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.0649384930729866], Loss_Generator--[7.82232141494751],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.14360511302947998], Loss_Generator--[3.6899514198303223],Accuracy--[33.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.055619291961193085], Loss_Generator--[4.094673156738281],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.28748559951782227], Loss_Generator--[2.6677181720733643],Accuracy--[46.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.01585070788860321], Loss_Generator--[5.571920394897461],Accuracy--[28.999999999999996]
# Epoch--[26 / 100], Loss_Discriminator--[0.04057222604751587], Loss_Generator--[2.8821420669555664],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.20122623443603516], Loss_Generator--[8.027023315429688],Accuracy--[45.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.07554251700639725], Loss_Generator--[8.525286674499512],Accuracy--[35.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.12906309962272644], Loss_Generator--[7.622555732727051],Accuracy--[46.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10132656991481781], Loss_Generator--[8.972887992858887],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.14429698884487152], Loss_Generator--[9.058856010437012],Accuracy--[31.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.10284000635147095], Loss_Generator--[8.17422103881836],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.4169458746910095], Loss_Generator--[5.414224624633789],Accuracy--[36.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.0681416392326355], Loss_Generator--[7.489997386932373],Accuracy--[37.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09683366864919662], Loss_Generator--[9.483597755432129],Accuracy--[39.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.09456047415733337], Loss_Generator--[8.406984329223633],Accuracy--[32.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.04193020612001419], Loss_Generator--[3.5319766998291016],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.1474384367465973], Loss_Generator--[4.920907497406006],Accuracy--[34.0]
# Epoch--[26 / 100], Loss_Discriminator--[0.4556313753128052], Loss_Generator--[4.566822052001953],Accuracy--[28.999999999999996]
# Epoch--[26 / 100], Loss_Discriminator--[-0.0882624089717865], Loss_Generator--[6.142786502838135],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.06572314351797104], Loss_Generator--[8.69754695892334],Accuracy--[41.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.08905777335166931], Loss_Generator--[10.908541679382324],Accuracy--[30.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.05878579244017601], Loss_Generator--[10.934354782104492],Accuracy--[38.0]
# Epoch--[26 / 100], Loss_Discriminator--[-0.11491747945547104], Loss_Generator--[11.78201675415039],Accuracy--[33.0]

# %%
torch.save(gen.state_dict(), 'gen.pth')
torch.save(disc.state_dict(), 'disc.pth')
